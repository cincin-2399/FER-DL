# %% [markdown]
# # import necessary libraries

# %%
import os
import argparse
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import cv2
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D
from keras.optimizers import Adam
from keras.layers import MaxPooling2D
from tensorflow.keras import layers, models, datasets, initializers
from tensorflow.keras.callbacks import ModelCheckpoint
from keras import backend as K
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve,auc
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score


#data preprocessing
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Loading the dataset and preprocessing

# %%
train_dir = '/kaggle/input/fer2013/train/'
val_dir = '/kaggle/input/fer2013/test/'

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(48,48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
     fill_mode = 'nearest',
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # Create the model

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Flatten, Dense, Dropout, concatenate
from tensorflow.keras.models import Model

def inception_module(x, filters):
    # 1x1 convolution
    conv1x1_1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu')(x)

    # 1x1 convolution followed by 3x3 convolution
    conv1x1_2 = Conv2D(filters[1], (1, 1), padding='same', activation='relu')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu')(conv1x1_2)

    # 1x1 convolution followed by 5x5 convolution
    conv1x1_3 = Conv2D(filters[3], (1, 1), padding='same', activation='relu')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu')(conv1x1_3)

    # 3x3 max pooling followed by 1x1 convolution
    maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    conv1x1_4 = Conv2D(filters[5], (1, 1), padding='same', activation='relu')(maxpool)

    # Concatenate all branches
    inception = concatenate([conv1x1_1, conv3x3, conv5x5, conv1x1_4], axis=-1)
    return inception

def GoogleNet(input_shape, num_classes):
    input_layer = Input(shape=input_shape)

    #initial 7x7 convolution layer
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(input_layer)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    #first Inception module
    x = inception_module(x, [64, 128, 128, 192, 32, 96])

    #additional Inception modules (you can add more as needed)
    x = inception_module(x, [64, 128, 128, 192, 32, 96])
    x = inception_module(x, [64, 128, 128, 192, 32, 96])

    #global Average Pooling
    x = AveragePooling2D((7, 7))(x)
    x = Flatten()(x)

    #fully connected layers
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.4)(x)

    #output layer
    output_layer = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=input_layer, outputs=output_layer)
    return model

input_shape = (48, 48, 1)  
num_classes = 7  
model = GoogleNet(input_shape, num_classes)
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 24, 24, 64)           3200      ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 12, 12, 64)           0         ['conv2d[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)          8320      ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 192)          12480     ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 64)           0         ['max_pooling2d[0][0]']
#  g2D)
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 64)           4160      ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)          147584    ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 32)           153632    ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 96)           6240      ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)   (None, 12, 12, 320)          0         ['conv2d_1[0][0]',
#                                                                      'conv2d_3[0][0]',
#                                                                      'conv2d_5[0][0]',
#                                                                      'conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 128)          41088     ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 12, 12, 192)          61632     ['concatenate[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 12, 320)          0         ['concatenate[0][0]']
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 64)           20544     ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 12, 12, 128)          147584    ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 12, 12, 32)           153632    ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 12, 12, 96)           30816     ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate  (None, 12, 12, 320)          0         ['conv2d_7[0][0]',
#  )                                                                   'conv2d_9[0][0]',
#                                                                      'conv2d_11[0][0]',
#                                                                      'conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 12, 12, 128)          41088     ['concatenate_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 12, 12, 192)          61632     ['concatenate_1[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 12, 320)          0         ['concatenate_1[0][0]']
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 12, 12, 64)           20544     ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 12, 12, 128)          147584    ['conv2d_14[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 12, 12, 32)           153632    ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 12, 12, 96)           30816     ['max_pooling2d_3[0][0]']
#
#  concatenate_2 (Concatenate  (None, 12, 12, 320)          0         ['conv2d_13[0][0]',
#  )                                                                   'conv2d_15[0][0]',
#                                                                      'conv2d_17[0][0]',
#                                                                      'conv2d_18[0][0]']
#
#  average_pooling2d (Average  (None, 1, 1, 320)            0         ['concatenate_2[0][0]']
#  Pooling2D)
#
#  flatten (Flatten)           (None, 320)                  0         ['average_pooling2d[0][0]']
#
#  dense (Dense)               (None, 1024)                 328704    ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 1024)                 0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 7)                    7175      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 1582087 (6.04 MB)
# Trainable params: 1582087 (6.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # Train the model

# %%
checkpoint = ModelCheckpoint('googleNet_emotion.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=50,  # Adjust the number of epochs as needed
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/50
# 448/448 [==============================] - ETA: 0s - loss: 1.8083 - accuracy: 0.2487
# Epoch 1: val_accuracy improved from -inf to 0.24791, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 163s 327ms/step - loss: 1.8083 - accuracy: 0.2487 - val_loss: 1.7882 - val_accuracy: 0.2479
# Epoch 2/50
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 448/448 [==============================] - ETA: 0s - loss: 1.7826 - accuracy: 0.2591
# Epoch 2: val_accuracy improved from 0.24791 to 0.26451, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 33s 72ms/step - loss: 1.7826 - accuracy: 0.2591 - val_loss: 1.7579 - val_accuracy: 0.2645
# Epoch 3/50
# 448/448 [==============================] - ETA: 0s - loss: 1.7072 - accuracy: 0.3006
# Epoch 3: val_accuracy improved from 0.26451 to 0.37263, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 32s 70ms/step - loss: 1.7072 - accuracy: 0.3006 - val_loss: 1.6148 - val_accuracy: 0.3726
# Epoch 4/50
# 448/448 [==============================] - ETA: 0s - loss: 1.5907 - accuracy: 0.3741
# Epoch 4: val_accuracy improved from 0.37263 to 0.40751, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 31s 69ms/step - loss: 1.5907 - accuracy: 0.3741 - val_loss: 1.5299 - val_accuracy: 0.4075
# Epoch 5/50
# 447/448 [============================>.] - ETA: 0s - loss: 1.4988 - accuracy: 0.4202
# Epoch 5: val_accuracy improved from 0.40751 to 0.43555, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 31s 69ms/step - loss: 1.4988 - accuracy: 0.4204 - val_loss: 1.4634 - val_accuracy: 0.4355
# Epoch 6/50
# 447/448 [============================>.] - ETA: 0s - loss: 1.4338 - accuracy: 0.4515
# Epoch 6: val_accuracy improved from 0.43555 to 0.46959, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 1.4337 - accuracy: 0.4515 - val_loss: 1.3862 - val_accuracy: 0.4696
# Epoch 7/50
# 448/448 [==============================] - ETA: 0s - loss: 1.3722 - accuracy: 0.4728
# Epoch 7: val_accuracy improved from 0.46959 to 0.48926, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 31s 68ms/step - loss: 1.3722 - accuracy: 0.4728 - val_loss: 1.3296 - val_accuracy: 0.4893
# Epoch 8/50
# 448/448 [==============================] - ETA: 0s - loss: 1.3131 - accuracy: 0.5008
# Epoch 8: val_accuracy improved from 0.48926 to 0.48968, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 30s 67ms/step - loss: 1.3131 - accuracy: 0.5008 - val_loss: 1.3176 - val_accuracy: 0.4897
# Epoch 9/50
# 447/448 [============================>.] - ETA: 0s - loss: 1.2583 - accuracy: 0.5232
# Epoch 9: val_accuracy improved from 0.48968 to 0.52190, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 30s 67ms/step - loss: 1.2589 - accuracy: 0.5231 - val_loss: 1.2530 - val_accuracy: 0.5219
# Epoch 10/50
# 448/448 [==============================] - ETA: 0s - loss: 1.2084 - accuracy: 0.5396
# Epoch 10: val_accuracy improved from 0.52190 to 0.52999, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 1.2084 - accuracy: 0.5396 - val_loss: 1.2325 - val_accuracy: 0.5300
# Epoch 11/50
# 448/448 [==============================] - ETA: 0s - loss: 1.1542 - accuracy: 0.5638
# Epoch 11: val_accuracy did not improve from 0.52999
# 448/448 [==============================] - 30s 67ms/step - loss: 1.1542 - accuracy: 0.5638 - val_loss: 1.2541 - val_accuracy: 0.5240
# Epoch 12/50
# 448/448 [==============================] - ETA: 0s - loss: 1.1096 - accuracy: 0.5829
# Epoch 12: val_accuracy improved from 0.52999 to 0.53809, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 31s 68ms/step - loss: 1.1096 - accuracy: 0.5829 - val_loss: 1.2134 - val_accuracy: 0.5381
# Epoch 13/50
# 448/448 [==============================] - ETA: 0s - loss: 1.0644 - accuracy: 0.5957
# Epoch 13: val_accuracy improved from 0.53809 to 0.54869, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 30s 68ms/step - loss: 1.0644 - accuracy: 0.5957 - val_loss: 1.1864 - val_accuracy: 0.5487
# Epoch 14/50
# 448/448 [==============================] - ETA: 0s - loss: 1.0128 - accuracy: 0.6176
# Epoch 14: val_accuracy improved from 0.54869 to 0.55845, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 29s 65ms/step - loss: 1.0128 - accuracy: 0.6176 - val_loss: 1.1998 - val_accuracy: 0.5585
# Epoch 15/50
# 447/448 [============================>.] - ETA: 0s - loss: 0.9622 - accuracy: 0.6378
# Epoch 15: val_accuracy improved from 0.55845 to 0.56083, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 31s 69ms/step - loss: 0.9623 - accuracy: 0.6377 - val_loss: 1.2143 - val_accuracy: 0.5608
# Epoch 16/50
# 448/448 [==============================] - ETA: 0s - loss: 0.9048 - accuracy: 0.6575
# Epoch 16: val_accuracy did not improve from 0.56083
# 448/448 [==============================] - 30s 67ms/step - loss: 0.9048 - accuracy: 0.6575 - val_loss: 1.2051 - val_accuracy: 0.5565
# Epoch 17/50
# 448/448 [==============================] - ETA: 0s - loss: 0.8488 - accuracy: 0.6823
# Epoch 17: val_accuracy did not improve from 0.56083
# 448/448 [==============================] - 31s 69ms/step - loss: 0.8488 - accuracy: 0.6823 - val_loss: 1.2521 - val_accuracy: 0.5547
# Epoch 18/50
# 447/448 [============================>.] - ETA: 0s - loss: 0.7910 - accuracy: 0.7037
# Epoch 18: val_accuracy did not improve from 0.56083
# 448/448 [==============================] - 32s 71ms/step - loss: 0.7907 - accuracy: 0.7039 - val_loss: 1.3092 - val_accuracy: 0.5559
# Epoch 19/50
# 448/448 [==============================] - ETA: 0s - loss: 0.7251 - accuracy: 0.7306
# Epoch 19: val_accuracy did not improve from 0.56083
# 448/448 [==============================] - 37s 82ms/step - loss: 0.7251 - accuracy: 0.7306 - val_loss: 1.3394 - val_accuracy: 0.5569
# Epoch 20/50
# 448/448 [==============================] - ETA: 0s - loss: 0.6650 - accuracy: 0.7560
# Epoch 20: val_accuracy did not improve from 0.56083
# 448/448 [==============================] - 37s 82ms/step - loss: 0.6650 - accuracy: 0.7560 - val_loss: 1.4208 - val_accuracy: 0.5545
# Epoch 21/50
# 448/448 [==============================] - ETA: 0s - loss: 0.6005 - accuracy: 0.7787
# Epoch 21: val_accuracy improved from 0.56083 to 0.56641, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 36s 79ms/step - loss: 0.6005 - accuracy: 0.7787 - val_loss: 1.4477 - val_accuracy: 0.5664
# Epoch 22/50
# 448/448 [==============================] - ETA: 0s - loss: 0.5374 - accuracy: 0.7995
# Epoch 22: val_accuracy did not improve from 0.56641
# 448/448 [==============================] - 34s 76ms/step - loss: 0.5374 - accuracy: 0.7995 - val_loss: 1.5489 - val_accuracy: 0.5580
# Epoch 23/50
# 448/448 [==============================] - ETA: 0s - loss: 0.4873 - accuracy: 0.8217
# Epoch 23: val_accuracy did not improve from 0.56641
# 448/448 [==============================] - 31s 69ms/step - loss: 0.4873 - accuracy: 0.8217 - val_loss: 1.7077 - val_accuracy: 0.5543
# Epoch 24/50
# 448/448 [==============================] - ETA: 0s - loss: 0.4327 - accuracy: 0.8409
# Epoch 24: val_accuracy did not improve from 0.56641
# 448/448 [==============================] - 32s 71ms/step - loss: 0.4327 - accuracy: 0.8409 - val_loss: 1.6948 - val_accuracy: 0.5442
# Epoch 25/50
# 448/448 [==============================] - ETA: 0s - loss: 0.3820 - accuracy: 0.8606
# Epoch 25: val_accuracy did not improve from 0.56641
# 448/448 [==============================] - 30s 67ms/step - loss: 0.3820 - accuracy: 0.8606 - val_loss: 1.8527 - val_accuracy: 0.5552
# Epoch 26/50
# 448/448 [==============================] - ETA: 0s - loss: 0.3462 - accuracy: 0.8752
# Epoch 26: val_accuracy improved from 0.56641 to 0.56780, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 33s 73ms/step - loss: 0.3462 - accuracy: 0.8752 - val_loss: 1.9884 - val_accuracy: 0.5678
# Epoch 27/50
# 448/448 [==============================] - ETA: 0s - loss: 0.3052 - accuracy: 0.8916
# Epoch 27: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 32s 71ms/step - loss: 0.3052 - accuracy: 0.8916 - val_loss: 2.0276 - val_accuracy: 0.5612
# Epoch 28/50
# 447/448 [============================>.] - ETA: 0s - loss: 0.2687 - accuracy: 0.9026
# Epoch 28: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 32s 72ms/step - loss: 0.2690 - accuracy: 0.9024 - val_loss: 2.1439 - val_accuracy: 0.5529
# Epoch 29/50
# 448/448 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.9071
# Epoch 29: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 30s 67ms/step - loss: 0.2593 - accuracy: 0.9071 - val_loss: 2.1951 - val_accuracy: 0.5495
# Epoch 30/50
# 448/448 [==============================] - ETA: 0s - loss: 0.2283 - accuracy: 0.9183
# Epoch 30: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 32s 72ms/step - loss: 0.2283 - accuracy: 0.9183 - val_loss: 2.1978 - val_accuracy: 0.5488
# Epoch 31/50
# 448/448 [==============================] - ETA: 0s - loss: 0.2071 - accuracy: 0.9269
# Epoch 31: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 33s 73ms/step - loss: 0.2071 - accuracy: 0.9269 - val_loss: 2.3891 - val_accuracy: 0.5596
# Epoch 32/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1882 - accuracy: 0.9337
# Epoch 32: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 32s 70ms/step - loss: 0.1882 - accuracy: 0.9337 - val_loss: 2.5120 - val_accuracy: 0.5638
# Epoch 33/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.9333
# Epoch 33: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 32s 71ms/step - loss: 0.1894 - accuracy: 0.9333 - val_loss: 2.5459 - val_accuracy: 0.5653
# Epoch 34/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1787 - accuracy: 0.9380
# Epoch 34: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 31s 69ms/step - loss: 0.1787 - accuracy: 0.9380 - val_loss: 2.5185 - val_accuracy: 0.5578
# Epoch 35/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1648 - accuracy: 0.9402
# Epoch 35: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 32s 72ms/step - loss: 0.1648 - accuracy: 0.9402 - val_loss: 2.7632 - val_accuracy: 0.5484
# Epoch 36/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1376 - accuracy: 0.9538
# Epoch 36: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 31s 69ms/step - loss: 0.1376 - accuracy: 0.9538 - val_loss: 2.8000 - val_accuracy: 0.5571
# Epoch 37/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9463
# Epoch 37: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 31s 69ms/step - loss: 0.1569 - accuracy: 0.9463 - val_loss: 2.8500 - val_accuracy: 0.5558
# Epoch 38/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9541
# Epoch 38: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 31s 70ms/step - loss: 0.1344 - accuracy: 0.9541 - val_loss: 2.8159 - val_accuracy: 0.5571
# Epoch 39/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9536
# Epoch 39: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 33s 73ms/step - loss: 0.1349 - accuracy: 0.9536 - val_loss: 2.7906 - val_accuracy: 0.5604
# Epoch 40/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.9589
# Epoch 40: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 31s 69ms/step - loss: 0.1214 - accuracy: 0.9589 - val_loss: 2.7331 - val_accuracy: 0.5551
# Epoch 41/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1394 - accuracy: 0.9516
# Epoch 41: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 32s 71ms/step - loss: 0.1394 - accuracy: 0.9516 - val_loss: 2.9209 - val_accuracy: 0.5580
# Epoch 42/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9599
# Epoch 42: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 31s 70ms/step - loss: 0.1192 - accuracy: 0.9599 - val_loss: 3.0286 - val_accuracy: 0.5519
# Epoch 43/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9622
# Epoch 43: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 32s 71ms/step - loss: 0.1132 - accuracy: 0.9622 - val_loss: 2.8942 - val_accuracy: 0.5565
# Epoch 44/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9632
# Epoch 44: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 31s 68ms/step - loss: 0.1072 - accuracy: 0.9632 - val_loss: 3.0161 - val_accuracy: 0.5557
# Epoch 45/50
# 448/448 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9573
# Epoch 45: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 32s 71ms/step - loss: 0.1243 - accuracy: 0.9573 - val_loss: 2.9816 - val_accuracy: 0.5526
# Epoch 46/50
# 448/448 [==============================] - ETA: 0s - loss: 0.0941 - accuracy: 0.9682
# Epoch 46: val_accuracy did not improve from 0.56780
# 448/448 [==============================] - 32s 71ms/step - loss: 0.0941 - accuracy: 0.9682 - val_loss: 3.0419 - val_accuracy: 0.5536
# Epoch 47/50
# 447/448 [============================>.] - ETA: 0s - loss: 0.1165 - accuracy: 0.9586
# Epoch 47: val_accuracy improved from 0.56780 to 0.56948, saving model to googleNet_emotion.h5
# 448/448 [==============================] - 32s 72ms/step - loss: 0.1166 - accuracy: 0.9586 - val_loss: 3.3121 - val_accuracy: 0.5695
# Epoch 48/50
# 448/448 [==============================] - ETA: 0s - loss: 0.0971 - accuracy: 0.9665
# Epoch 48: val_accuracy did not improve from 0.56948
# 448/448 [==============================] - 30s 67ms/step - loss: 0.0971 - accuracy: 0.9665 - val_loss: 3.2435 - val_accuracy: 0.5604
# Epoch 49/50
# 447/448 [============================>.] - ETA: 0s - loss: 0.1006 - accuracy: 0.9661
# Epoch 49: val_accuracy did not improve from 0.56948
# 448/448 [==============================] - 31s 69ms/step - loss: 0.1006 - accuracy: 0.9661 - val_loss: 3.1451 - val_accuracy: 0.5592
# Epoch 50/50
# 447/448 [============================>.] - ETA: 0s - loss: 0.1015 - accuracy: 0.9671
# Epoch 50: val_accuracy did not improve from 0.56948
# 448/448 [==============================] - 31s 69ms/step - loss: 0.1017 - accuracy: 0.9670 - val_loss: 3.1633 - val_accuracy: 0.5587

# %% [markdown]
# # Save the model

# %%
model.save('/kaggle/working/googleNet_emotion.h5')

# %% [markdown]
# # Evaluation and Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
import numpy as np

def evaluate_model(model, data_generator):
    predictions = model.predict(data_generator)
    true_labels = np.array(data_generator.labels)
    pred_labels = np.argmax(predictions, axis=1)

    acc = accuracy_score(true_labels, pred_labels)
    precision = precision_score(true_labels, pred_labels, average='weighted')
    recall = recall_score(true_labels, pred_labels, average='weighted')
    f1 = f1_score(true_labels, pred_labels, average='weighted')

    print("Accuracy:", acc)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)

    conf_matrix = confusion_matrix(true_labels, pred_labels)
    print("\nConfusion Matrix:")
    print(conf_matrix)

evaluate_model(model, validation_generator)
# Out:
# 113/113 [==============================] - 6s 51ms/step
# Accuracy: 0.17762607968793537
# Precision: 0.1741079989282378
# Recall: 0.17762607968793537
# F1 Score: 0.17434617390028073
#
# Confusion Matrix:
# [[151   7 102 259 197 139 103]
#  [ 17   2   5  30  24  15  18]
#  [164  18  93 290 206 132 121]
#  [310  12 154 510 334 274 180]
#  [204  20 110 334 236 204 125]
#  [207  10 119 328 256 197 130]
#  [133  12  75 236 160 129  86]]

# %% [markdown]
# # Training VS Validation Accuracy

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # ROC Curve

# %%
y_pred = model.predict(validation_generator)
y_true = validation_generator.classes

plt.figure(figsize=(12, 8))
for i in range(len(train_generator.class_indices)):
    fpr, tpr, _ = roc_curve(y_true == i, y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Each Class')
plt.legend()
plt.show()
# Out:
# 113/113 [==============================] - 6s 56ms/step

# %%
y_pred_classes = np.argmax(y_pred, axis=1)
class_report = classification_report(y_true, y_pred_classes, target_names=train_generator.class_indices.keys())
print('Classification Report:\n', class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.13      0.16      0.14       958
#      disgust       0.01      0.01      0.01       111
#         fear       0.14      0.09      0.11      1024
#        happy       0.25      0.28      0.27      1774
#      neutral       0.18      0.21      0.19      1233
#          sad       0.17      0.15      0.16      1247
#     surprise       0.11      0.10      0.11       831
#
#     accuracy                           0.18      7178
#    macro avg       0.14      0.14      0.14      7178
# weighted avg       0.17      0.18      0.17      7178
